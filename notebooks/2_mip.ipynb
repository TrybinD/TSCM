# %%
import pandas as pd
from time import time

from src.data.problem import Problem

from src.solvers.mip_solver import PaperMIPSolver, MIPSolver

from src.utils import calculate_costs

# %%
example_problem = Problem.from_example()

# %%
dataset_data_params = [(1, 5, 10, 10), (2, 5, 10, 10), (3, 5, 10, 10), 
                       (1, 5, 5, 5), (2, 5, 5, 5), (3, 5, 5, 5),
                       (1, 10, 10, 10), (2, 10, 10, 10), (3, 10, 10, 10), 
                       (1, 5, 10, 20), (2, 5, 10, 20), (3, 5, 10, 20), 
                       (1, 5, 20, 10), (2, 5, 20, 10), (3, 5, 20, 10), 
                       (1, 5, 20, 20), (2, 5, 20, 20), (3, 5, 20, 20)]

# %% [markdown]
# ### Proble from Paper

# %% [markdown]
# Using the exact formulation of the problem (with minor corrections) from the paper

# %%
mip_solver = PaperMIPSolver(max_time=60)
start = time()
solution = mip_solver.solve(example_problem)
run_time = time() - start
solution, run_time
# Out:
# ({'Operation1': {'Subtask1': 'Erfurt',
#    'Subtask2': 'Erfurt',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation2': {'Subtask1': 'Hannover',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask9': 'Dusseldorf',
#    'Subtask10': 'Bremen'},
#   'Operation3': {'Subtask1': 'Hannover',
#    'Subtask4': 'Bremen',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation4': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation5': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'}},
#  1.224163293838501)

# %%
calculate_costs(example_problem, solution)
# Out:
# np.float64(8253.642421344399)

# %%
solutions = {"example": {"cost": calculate_costs(example_problem, solution), "solution": solution, "time": run_time}}

# %%
for param in dataset_data_params:
    number, operations, sub_operations, cities = param
    print(f"operations-{operations},sub_operations-{sub_operations},cities-{cities}-{number}")
    p = Problem.from_dataset(number, operations, sub_operations, cities)
    start = time()
    solution = mip_solver.solve(p)
    run_time = time() - start

    solutions[f"{operations},{sub_operations},{cities}-{number}"] = {"cost": calculate_costs(p, solution), 
                                                                     "solution": solution, 
                                                                     "time": run_time}
# Out:
# operations-5,sub_operations-10,cities-10-1
# operations-5,sub_operations-10,cities-10-2
# operations-5,sub_operations-10,cities-10-3
# operations-5,sub_operations-5,cities-5-1
# operations-5,sub_operations-5,cities-5-2
# operations-5,sub_operations-5,cities-5-3
# operations-10,sub_operations-10,cities-10-1
# operations-10,sub_operations-10,cities-10-2
# operations-10,sub_operations-10,cities-10-3
# operations-5,sub_operations-10,cities-20-1
# operations-5,sub_operations-10,cities-20-2
# operations-5,sub_operations-10,cities-20-3
# operations-5,sub_operations-20,cities-10-1
# operations-5,sub_operations-20,cities-10-2
# operations-5,sub_operations-20,cities-10-3
# operations-5,sub_operations-20,cities-20-1
# operations-5,sub_operations-20,cities-20-2
# operations-5,sub_operations-20,cities-20-3

# %%
df_result = pd.DataFrame(solutions).T
df_result
# Out:
#                     cost                                           solution  \
# example      8253.642421  {'Operation1': {'Subtask1': 'Erfurt', 'Subtask...
# 5,10,10-1    4131.125634  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,10-2    5503.321218  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,10,10-3     5849.87106  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,5,5-1      2576.598208  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,5,5-2      5425.946189  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-3      6149.624015  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 10,10,10-1   9761.358987  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 10,10,10-2  10921.079954  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 10,10,10-3  11187.172451  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,10,20-1    3548.963825  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,20-2    4524.805988  {'Operation1': {'Sub-operation1': 'city13', 'S...
# 5,10,20-3    5452.526426  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,20,10-1   10879.150753  {'Operation1': {'Sub-operation3': 'city7', 'Su...
# 5,20,10-2   12360.110746  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,10-3   13205.052471  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,20-1   10037.328502  {'Operation1': {'Sub-operation3': 'city7', 'Su...
# 5,20,20-2   11496.384328  {'Operation1': {'Sub-operation1': 'city16', 'S...
# 5,20,20-3   12724.931577  {'Operation1': {'Sub-operation1': 'city15', 'S...
#
#                  time
# example      1.224163
# 5,10,10-1    0.832619
# 5,10,10-2    1.569982
# 5,10,10-3    2.316133
# 5,5,5-1      0.047644
# 5,5,5-2      0.057253
# 5,5,5-3      0.102458
# 10,10,10-1   3.621447
# 10,10,10-2   3.398963
# 10,10,10-3   2.623907
# 5,10,20-1   28.205571
# 5,10,20-2   46.294328
# 5,10,20-3   60.791091
# 5,20,10-1   60.409412
# 5,20,10-2   60.551619
# 5,20,10-3   60.514683
# 5,20,20-1   61.657185
# 5,20,20-2   61.720897
# 5,20,20-3    61.68613

# %%
df_result.to_csv("../data/solutions/mip_paper.csv", index=True)

# %% [markdown]
# ### MIP Simplified

# %% [markdown]
# The exact formulation of the problem is divided into n subtasks to reduce the search dimension

# %%
mip_solver = MIPSolver(max_time=10)
start = time()
solution = mip_solver.solve(example_problem)
run_time = time() - start
solution, run_time
# Out:
# ({'Operation1': {'Subtask1': 'Erfurt',
#    'Subtask2': 'Erfurt',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation2': {'Subtask1': 'Hannover',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask9': 'Dusseldorf',
#    'Subtask10': 'Bremen'},
#   'Operation3': {'Subtask1': 'Hannover',
#    'Subtask4': 'Bremen',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation4': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation5': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'}},
#  1.203101634979248)

# %%
calculate_costs(example_problem, solution)
# Out:
# np.float64(8253.642421344399)

# %%
solutions = {"example": {"cost": calculate_costs(example_problem, solution), "solution": solution, "time": run_time}}

# %%
for param in dataset_data_params:
    number, operations, sub_operations, cities = param
    print(f"operations-{operations},sub_operations-{sub_operations},cities-{cities}-{number}")
    p = Problem.from_dataset(number, operations, sub_operations, cities)
    start = time()
    solution = mip_solver.solve(p)
    run_time = time() - start

    solutions[f"{operations},{sub_operations},{cities}-{number}"] = {"cost": calculate_costs(p, solution), 
                                                                     "solution": solution, 
                                                                     "time": run_time}
# Out:
# operations-5,sub_operations-10,cities-10-1
# operations-5,sub_operations-10,cities-10-2
# operations-5,sub_operations-10,cities-10-3
# operations-5,sub_operations-5,cities-5-1
# operations-5,sub_operations-5,cities-5-2
# operations-5,sub_operations-5,cities-5-3
# operations-10,sub_operations-10,cities-10-1
# operations-10,sub_operations-10,cities-10-2
# operations-10,sub_operations-10,cities-10-3
# operations-5,sub_operations-10,cities-20-1
# operations-5,sub_operations-10,cities-20-2
# operations-5,sub_operations-10,cities-20-3
# operations-5,sub_operations-20,cities-10-1
# operations-5,sub_operations-20,cities-10-2
# operations-5,sub_operations-20,cities-10-3
# operations-5,sub_operations-20,cities-20-1
# operations-5,sub_operations-20,cities-20-2
# operations-5,sub_operations-20,cities-20-3

# %%
df_result = pd.DataFrame(solutions).T
df_result
# Out:
#                     cost                                           solution  \
# example      8253.642421  {'Operation1': {'Subtask1': 'Erfurt', 'Subtask...
# 5,10,10-1    4131.125634  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,10-2    5503.321218  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,10,10-3     5849.87106  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,5,5-1      2576.598208  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,5,5-2      5425.946189  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-3      6149.624015  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 10,10,10-1   9761.358987  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 10,10,10-2  10921.079954  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 10,10,10-3  11187.172451  {'Operation1': {'Sub-operation1': 'city2', 'Su...
# 5,10,20-1    3548.963825  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,20-2    4524.805988  {'Operation1': {'Sub-operation1': 'city13', 'S...
# 5,10,20-3    4955.329235  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,20,10-1   10687.468451  {'Operation1': {'Sub-operation3': 'city7', 'Su...
# 5,20,10-2   12147.769571  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,10-3   12960.070144  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,20-1    9163.294705  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,20,20-2    11025.58768  {'Operation1': {'Sub-operation1': 'city16', 'S...
# 5,20,20-3    11642.74129  {'Operation1': {'Sub-operation1': 'city15', 'S...
#
#                  time
# example      1.203102
# 5,10,10-1    0.683056
# 5,10,10-2     1.06692
# 5,10,10-3    1.087325
# 5,5,5-1      0.048534
# 5,5,5-2      0.104208
# 5,5,5-3      0.155079
# 10,10,10-1   1.752874
# 10,10,10-2   1.902112
# 10,10,10-3   2.140545
# 5,10,20-1    3.112474
# 5,10,20-2    6.114651
# 5,10,20-3    8.076928
# 5,20,10-1    5.749873
# 5,20,10-2    6.679742
# 5,20,10-3     8.40156
# 5,20,20-1   40.868999
# 5,20,20-2    45.16463
# 5,20,20-3   44.707953

# %%
df_result.to_csv("../data/solutions/mip.csv", index=True)
