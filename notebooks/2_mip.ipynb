# %%
import pandas as pd
from time import time

from src.data.problem import Problem

from src.solvers.mip_solver import PaperMIPSolver, MIPSolver

from src.utils import calculate_costs

# %%
example_problem = Problem.from_example()

# %%
dataset_data_params = [(1, 5, 10, 10), (2, 5, 10, 10), (3, 5, 10, 10), 
                       (1, 5, 5, 5), (2, 5, 5, 5), (3, 5, 5, 5),
                       (1, 10, 10, 10), (2, 10, 10, 10), (3, 10, 10, 10), 
                       (1, 5, 10, 20), (2, 5, 10, 20), (3, 5, 10, 20), 
                       (1, 5, 20, 10), (2, 5, 20, 10), (3, 5, 20, 10), 
                       (1, 5, 20, 20), (2, 5, 20, 20), (3, 5, 20, 20)]

# %% [markdown]
# ### Proble from Paper

# %% [markdown]
# Using the exact formulation of the problem (with minor corrections) from the paper

# %%
mip_solver = PaperMIPSolver(max_time=60)
start = time()
solution = mip_solver.solve(example_problem)
run_time = time() - start
solution, run_time
# Out:
# ({'Operation1': {'Subtask1': 'Erfurt',
#    'Subtask2': 'Erfurt',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation2': {'Subtask1': 'Hannover',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask9': 'Dusseldorf',
#    'Subtask10': 'Bremen'},
#   'Operation3': {'Subtask1': 'Hannover',
#    'Subtask4': 'Bremen',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation4': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation5': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'}},
#  1.2438228130340576)

# %%
calculate_costs(example_problem, solution)
# Out:
# np.float64(8253.642421344399)

# %%
solutions = {"example": {"cost": calculate_costs(example_problem, solution), "solution": solution, "time": run_time}}

# %%
for param in dataset_data_params:
    number, operations, sub_operations, cities = param
    print(f"operations-{operations},sub_operations-{sub_operations},cities-{cities}-{number}")
    p = Problem.from_dataset(number, operations, sub_operations, cities)
    start = time()
    solution = mip_solver.solve(p)
    run_time = time() - start

    solutions[f"{operations},{sub_operations},{cities}-{number}"] = {"cost": calculate_costs(p, solution), 
                                                                     "solution": solution, 
                                                                     "time": run_time}
# Out:
# operations-5,sub_operations-10,cities-10-1
# operations-5,sub_operations-10,cities-10-2
# operations-5,sub_operations-10,cities-10-3
# operations-5,sub_operations-5,cities-5-1
# operations-5,sub_operations-5,cities-5-2
# operations-5,sub_operations-5,cities-5-3
# operations-10,sub_operations-10,cities-10-1
# operations-10,sub_operations-10,cities-10-2
# operations-10,sub_operations-10,cities-10-3
# operations-5,sub_operations-10,cities-20-1
# operations-5,sub_operations-10,cities-20-2
# operations-5,sub_operations-10,cities-20-3
# operations-5,sub_operations-20,cities-10-1
# operations-5,sub_operations-20,cities-10-2
# operations-5,sub_operations-20,cities-10-3
# operations-5,sub_operations-20,cities-20-1
# operations-5,sub_operations-20,cities-20-2
# operations-5,sub_operations-20,cities-20-3

# %%
df_result = pd.DataFrame(solutions).T
df_result
# Out:
#                     cost                                           solution  \
# example      8253.642421  {'Operation1': {'Subtask1': 'Erfurt', 'Subtask...
# 5,10,10-1    5086.083142  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,10-2    7352.656259  {'Operation1': {'Sub-operation1': 'city9', 'Su...
# 5,10,10-3    7652.315227  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-1      2648.629467  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,5,5-2      5944.423926  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-3      6653.881317  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 10,10,10-1  12262.872326  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 10,10,10-2   14887.56828  {'Operation1': {'Sub-operation1': 'city9', 'Su...
# 10,10,10-3  14344.918524  {'Operation1': {'Sub-operation1': 'city6', 'Su...
# 5,10,20-1     4291.70812  {'Operation1': {'Sub-operation3': 'city14', 'S...
# 5,10,20-2    6000.298831  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,10,20-3    7041.799468  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,20,10-1   14183.507673  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,20,10-2   16075.222061  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,10-3   19856.909808  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,20-1   13978.901013  {'Operation1': {'Sub-operation3': 'city9', 'Su...
# 5,20,20-2   19240.863965  {'Operation1': {'Sub-operation1': 'city16', 'S...
# 5,20,20-3   18079.583759  {'Operation1': {'Sub-operation1': 'city17', 'S...
#
#                  time
# example      1.243823
# 5,10,10-1    3.123233
# 5,10,10-2   34.767781
# 5,10,10-3   60.248046
# 5,5,5-1       0.04702
# 5,5,5-2      0.097665
# 5,5,5-3       0.08484
# 10,10,10-1  60.346164
# 10,10,10-2  60.425257
# 10,10,10-3  60.446829
# 5,10,20-1   60.638476
# 5,10,20-2    60.79804
# 5,10,20-3   60.903034
# 5,20,10-1   60.482765
# 5,20,10-2   60.504735
# 5,20,10-3   60.551018
# 5,20,20-1    61.67456
# 5,20,20-2   61.803779
# 5,20,20-3   61.919801

# %%
df_result.to_csv("../data/solutions/mip_paper.csv", index=True)

# %% [markdown]
# ### MIP Simplified

# %% [markdown]
# The exact formulation of the problem is divided into n subtasks to reduce the search dimension

# %%
mip_solver = MIPSolver(max_time=10)
start = time()
solution = mip_solver.solve(example_problem)
run_time = time() - start
solution, run_time
# Out:
# ({'Operation1': {'Subtask1': 'Erfurt',
#    'Subtask2': 'Erfurt',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation2': {'Subtask1': 'Hannover',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask9': 'Dusseldorf',
#    'Subtask10': 'Bremen'},
#   'Operation3': {'Subtask1': 'Hannover',
#    'Subtask4': 'Bremen',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation4': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'},
#   'Operation5': {'Subtask1': 'Hannover',
#    'Subtask2': 'Dresden',
#    'Subtask3': 'Dresden',
#    'Subtask4': 'Frankfurt',
#    'Subtask5': 'Hamburg',
#    'Subtask6': 'Berlin',
#    'Subtask7': 'Hannover',
#    'Subtask8': 'Erfurt',
#    'Subtask9': 'Erfurt',
#    'Subtask10': 'Bremen'}},
#  1.535369873046875)

# %%
calculate_costs(example_problem, solution)
# Out:
# np.float64(8253.642421344399)

# %%
solutions = {"example": {"cost": calculate_costs(example_problem, solution), "solution": solution, "time": run_time}}

# %%
for param in dataset_data_params:
    number, operations, sub_operations, cities = param
    print(f"operations-{operations},sub_operations-{sub_operations},cities-{cities}-{number}")
    p = Problem.from_dataset(number, operations, sub_operations, cities)
    start = time()
    solution = mip_solver.solve(p)
    run_time = time() - start

    solutions[f"{operations},{sub_operations},{cities}-{number}"] = {"cost": calculate_costs(p, solution), 
                                                                     "solution": solution, 
                                                                     "time": run_time}
# Out:
# operations-5,sub_operations-10,cities-10-1
# operations-5,sub_operations-10,cities-10-2
# operations-5,sub_operations-10,cities-10-3
# operations-5,sub_operations-5,cities-5-1
# operations-5,sub_operations-5,cities-5-2
# operations-5,sub_operations-5,cities-5-3
# operations-10,sub_operations-10,cities-10-1
# operations-10,sub_operations-10,cities-10-2
# operations-10,sub_operations-10,cities-10-3
# operations-5,sub_operations-10,cities-20-1
# operations-5,sub_operations-10,cities-20-2
# operations-5,sub_operations-10,cities-20-3
# operations-5,sub_operations-20,cities-10-1
# operations-5,sub_operations-20,cities-10-2
# operations-5,sub_operations-20,cities-10-3
# operations-5,sub_operations-20,cities-20-1
# operations-5,sub_operations-20,cities-20-2
# operations-5,sub_operations-20,cities-20-3

# %%
df_result = pd.DataFrame(solutions).T
df_result
# Out:
#                     cost                                           solution  \
# example      8253.642421  {'Operation1': {'Subtask1': 'Erfurt', 'Subtask...
# 5,10,10-1    5086.083142  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,10-2    7352.656259  {'Operation1': {'Sub-operation1': 'city9', 'Su...
# 5,10,10-3    7652.315227  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-1      2648.629467  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,5,5-2      5944.423926  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,5,5-3      6653.881317  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 10,10,10-1  12221.755638  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 10,10,10-2  14275.526163  {'Operation1': {'Sub-operation1': 'city9', 'Su...
# 10,10,10-3  14200.754292  {'Operation1': {'Sub-operation1': 'city4', 'Su...
# 5,10,20-1    4252.038054  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,10,20-2    5497.293768  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,10,20-3     5866.17632  {'Operation1': {'Sub-operation1': 'city11', 'S...
# 5,20,10-1   13512.960159  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,20,10-2   15848.544085  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,10-3   16703.557919  {'Operation1': {'Sub-operation1': 'city7', 'Su...
# 5,20,20-1   12502.185964  {'Operation1': {'Sub-operation3': 'city1', 'Su...
# 5,20,20-2   14939.882074  {'Operation1': {'Sub-operation1': 'city16', 'S...
# 5,20,20-3   16662.885276  {'Operation1': {'Sub-operation1': 'city19', 'S...
#
#                  time
# example       1.53537
# 5,10,10-1     1.14701
# 5,10,10-2    3.109695
# 5,10,10-3    1.800876
# 5,5,5-1      0.067034
# 5,5,5-2       0.19748
# 5,5,5-3      0.211816
# 10,10,10-1   2.826524
# 10,10,10-2   4.759965
# 10,10,10-3   2.896359
# 5,10,20-1    4.022932
# 5,10,20-2   10.731049
# 5,10,20-3   14.838309
# 5,20,10-1    11.58059
# 5,20,10-2   24.912745
# 5,20,10-3   25.348594
# 5,20,20-1   44.896727
# 5,20,20-2   51.476967
# 5,20,20-3    51.61555

# %%
df_result.to_csv("../data/solutions/mip.csv", index=True)
